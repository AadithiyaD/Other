# %%
#https://pandas.pydata.org/docs/reference/api/pandas.read_csv.html

# %% [markdown]
# """
#
# # Pandas
# ## Exploring data
# ### Methods to Load CSV Data File
# [Jupyter](https://www.tutorialspoint.com/jupyter/jupyter_notebook_markdown_cells.htm)
#
# [Data reading](https://www.tutorialspoint.com/machine_learning_with_python/machine_learning_with_python_data_loading_for_ml_projects.htm)
#
# **Bold**
#
# *italic*
#
# __BOLD__
#
# _italic_
#
# """

# %%
# %ls
# Out:
# sample_data/

# %%
# %cd drive/MyDrive/1-courses/courses/2021-22-odd-oops-MLA-OE/MLA-OE-Final\ new/code/mine/
# Out:
# [Errno 2] No such file or directory: 'drive/MyDrive/1-courses/courses/2021-22-odd-oops-MLA-OE/MLA-OE-Final new/code/mine/'
# /content

# %% [markdown]
# # Dictionary to Dataframe

# %%
import pandas as pd

# %%
data = {
    'name': ['Xavier', 'Ann', 'Jana', 'Yi', 'Robin', 'Amal', 'Nori'],
   'city': ['Mexico City', 'Toronto', 'Prague', 'Shanghai','Manchester', 'Cairo', 'Osaka'],
  'age': [41, 28, 33, 34, 38, 31, 37],
   'score': [88.0, 79.0, 81.0, 80.0, 68.0, 61.0, 84.0]
}

# %%
data
# Out:
# {'name': ['Xavier', 'Ann', 'Jana', 'Yi', 'Robin', 'Amal', 'Nori'],
#  'city': ['Mexico City',
#   'Toronto',
#   'Prague',
#   'Shanghai',
#   'Manchester',
#   'Cairo',
#   'Osaka'],
#  'age': [41, 28, 33, 34, 38, 31, 37],
#  'score': [88.0, 79.0, 81.0, 80.0, 68.0, 61.0, 84.0]}

# %%
type(data)
# Out:
# dict

# %%
row_labels = [101, 102, 103, 104, 105, 106, 107]

# %%
df = pd.DataFrame(data=data, index=row_labels)
df
# Out:
#        name         city  age  score
# 101  Xavier  Mexico City   41   88.0
# 102     Ann      Toronto   28   79.0
# 103    Jana       Prague   33   81.0
# 104      Yi     Shanghai   34   80.0
# 105   Robin   Manchester   38   68.0
# 106    Amal        Cairo   31   61.0
# 107    Nori        Osaka   37   84.0

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # Accessing Data

# %%
df.head()
# Out:
#        name         city  age  score
# 101  Xavier  Mexico City   41   88.0
# 102     Ann      Toronto   28   79.0
# 103    Jana       Prague   33   81.0
# 104      Yi     Shanghai   34   80.0
# 105   Robin   Manchester   38   68.0

# %%
df.head(2)
# Out:
#        name         city  age  score
# 101  Xavier  Mexico City   41   88.0
# 102     Ann      Toronto   28   79.0

# %%
df.tail()
# Out:
#       name        city  age  score
# 103   Jana      Prague   33   81.0
# 104     Yi    Shanghai   34   80.0
# 105  Robin  Manchester   38   68.0
# 106   Amal       Cairo   31   61.0
# 107   Nori       Osaka   37   84.0

# %%
df.tail(2)
# Out:
#      name   city  age  score
# 106  Amal  Cairo   31   61.0
# 107  Nori  Osaka   37   84.0

# %%
df['city']
# Out:
# 101    Mexico City
# 102        Toronto
# 103         Prague
# 104       Shanghai
# 105     Manchester
# 106          Cairo
# 107          Osaka
# Name: city, dtype: object

# %%
df.city
# Out:
# 101    Mexico City
# 102        Toronto
# 103         Prague
# 104       Shanghai
# 105     Manchester
# 106          Cairo
# 107          Osaka
# Name: city, dtype: object

# %%
cities=df['city']

# %%
type(cities)
# Out:
# pandas.core.series.Series

# %%
cities
# Out:
# 101    Mexico City
# 102        Toronto
# 103         Prague
# 104       Shanghai
# 105     Manchester
# 106          Cairo
# 107          Osaka
# Name: city, dtype: object

# %%
cities[102]
# Out:
# 'Toronto'

# %%
df[['city','name']]
# Out:
#             city    name
# 101  Mexico City  Xavier
# 102      Toronto     Ann
# 103       Prague    Jana
# 104     Shanghai      Yi
# 105   Manchester   Robin
# 106        Cairo    Amal
# 107        Osaka    Nori

# %%
df.loc[102]
# Out:
# name         Ann
# city     Toronto
# age           28
# score       79.0
# Name: 102, dtype: object

# %%
df.iloc[0]
# Out:
# name          Xavier
# city     Mexico City
# age               41
# score           88.0
# Name: 101, dtype: object

# %% [markdown]
# # Store Dataframe into CSV file

# %%
df.to_csv('data.csv')

# %% [markdown]
# # List to Dataframe

# %%
l = [[1, 2, 100], [2, 4, 100], [3, 8, 100]]
data=pd.DataFrame(l, columns=['x', 'y', 'z'])
data
# Out:
#    x  y    z
# 0  1  2  100
# 1  2  4  100
# 2  3  8  100

# %%
# %ls
# Out:
# data.csv  sample_data/

# %%
# %pwd
# Out:
# '/content'

# %% [markdown]
# # Reading Data

# %%
newdata=pd.read_csv('data.csv', index_col=0)

# %%
temp=pd.read_csv('data.csv')

# %%
temp
# Out:
#    Unnamed: 0    name         city  age  score
# 0         101  Xavier  Mexico City   41   88.0
# 1         102     Ann      Toronto   28   79.0
# 2         103    Jana       Prague   33   81.0
# 3         104      Yi     Shanghai   34   80.0
# 4         105   Robin   Manchester   38   68.0
# 5         106    Amal        Cairo   31   61.0
# 6         107    Nori        Osaka   37   84.0

# %%
newdata
# Out:
#        name         city  age  score
# 101  Xavier  Mexico City   41   88.0
# 102     Ann      Toronto   28   79.0
# 103    Jana       Prague   33   81.0
# 104      Yi     Shanghai   34   80.0
# 105   Robin   Manchester   38   68.0
# 106    Amal        Cairo   31   61.0
# 107    Nori        Osaka   37   84.0

# %% [markdown]
# # Analyze Data

# %%
newdata.columns
# Out:
# Index(['name', 'city', 'age', 'score'], dtype='object')

# %%
newdata.index
# Out:
# Int64Index([101, 102, 103, 104, 105, 106, 107], dtype='int64')

# %%
newdata.shape
# Out:
# (7, 4)

# %%
newdata.dtypes
# Out:
# name      object
# city      object
# age        int64
# score    float64
# dtype: object

# %%
import numpy as np

newdata_ = newdata.astype(dtype={'age': np.int32, 'score': np.float32})
newdata_.dtypes
# Out:
# name      object
# city      object
# age        int32
# score    float32
# dtype: object

# %%
newdata.ndim
# Out:
# 2

# %%
newdata.memory_usage()
# Out:
# Index    56
# name     56
# city     56
# age      56
# score    56
# dtype: int64

# %%
newdata_.memory_usage()
# Out:
# Index    56
# name     56
# city     56
# age      28
# score    28
# dtype: int64

# %% [markdown]
# In the example above, the last two columns, age and py-score, use 28 bytes of memory each. That’s because these columns have seven values, each of which is an integer that takes 32 bits, or 4 bytes. Seven integers times 4 bytes each equals a total of 28 bytes of memory usage.

# %%
newdata.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 7 entries, 101 to 107
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   name    7 non-null      object
#  1   city    7 non-null      object
#  2   age     7 non-null      int64
#  3   score   7 non-null      float64
# dtypes: float64(1), int64(1), object(2)
# memory usage: 280.0+ bytes

# %%
newdata.describe()
# Out:
#              age      score
# count   7.000000   7.000000
# mean   34.571429  77.285714
# std     4.429339   9.446592
# min    28.000000  61.000000
# 25%    32.000000  73.500000
# 50%    34.000000  80.000000
# 75%    37.500000  82.500000
# max    41.000000  88.000000

# %% [markdown]
# # Manipulate Data

# %%
newdata

# %%
newdata.loc[101]=['Ram','Chennai',21,88]

# %%
newdata
# Out:
#       name        city  age  score
# 101    Ram     Chennai   21   88.0
# 102    Ann     Toronto   28   79.0
# 103   Jana      Prague   33   81.0
# 104     Yi    Shanghai   34   80.0
# 105  Robin  Manchester   38   68.0
# 106   Amal       Cairo   31   61.0
# 107   Nori       Osaka   37   84.0

# %% [markdown]
# loc: only work on index
#
# iloc: work on position
#
# at: get scalar values. It's a very fast loc
#
# iat: Get scalar values. It's a very fast iloc
#
#
# at and iat are meant to access a scalar, that is, a single element in the dataframe, while loc and iloc are meant to access several elements at the same time, potentially to perform vectorized operations.

# %%
newdata.loc[101]
# Out:
# name         Ram
# city     Chennai
# age           21
# score       88.0
# Name: 101, dtype: object

# %%
newdata.iloc[0]
# Out:
# name         Ram
# city     Chennai
# age           21
# score       88.0
# Name: 101, dtype: object

# %%
newdata.iloc[0,1]
# Out:
# 'Chennai'

# %%
newdata.loc[101,'city']
# Out:
# 'Chennai'

# %%
newdata

# %%
newdata.loc[101,'city']='Delhi'

# %%
newdata
# Out:
#       name        city  age  score
# 101    Ram       Delhi   21   88.0
# 102    Ann     Toronto   28   79.0
# 103   Jana      Prague   33   81.0
# 104     Yi    Shanghai   34   80.0
# 105  Robin  Manchester   38   68.0
# 106   Amal       Cairo   31   61.0
# 107   Nori       Osaka   37   84.0

# %%
newdata.at[101]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-59-9975e5b47083> in <module>
# ----> 1 newdata.at[101]
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexing.py in __getitem__(self, key)
#    2273             return self.obj.loc[key]
#    2274
# -> 2275         return super().__getitem__(key)
#    2276
#    2277     def __setitem__(self, key, value):
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexing.py in __getitem__(self, key)
#    2220
#    2221         key = self._convert_key(key)
# -> 2222         return self.obj._get_value(*key, takeable=self._takeable)
#    2223
#    2224     def __setitem__(self, key, value):
#
# TypeError: _get_value() missing 1 required positional argument: 'col'

# %%
newdata.at[101,'name']
# Out:
# 'Ram'

# %%
newdata.at[101,'age']
# Out:
# 21

# %%
newdata
# Out:
#        name         city  age  py-score
# 101  Xavier  Mexico City   41      88.0
# 102     Ann      Toronto   28      79.0
# 103    Jana       Prague   33      81.0
# 104      Yi     Shanghai   34      80.0
# 105   Robin   Manchester   38      68.0
# 106    Amal        Cairo   31      61.0
# 107    Nori        Osaka   37      84.0

# %%
newdata.iat[0,1]
# Out:
# 'Delhi'

# %%
newdata.at[101,'age']=25

# %%
newdata
# Out:
#       name        city  age  py-score
# 101    Ram       Delhi   25      88.0
# 102    Ann     Toronto   28      79.0
# 103   Jana      Prague   33      81.0
# 104     Yi    Shanghai   34      80.0
# 105  Robin  Manchester   38      68.0
# 106   Amal       Cairo   31      61.0
# 107   Nori       Osaka   37      84.0

# %%
newdata.loc[101,'city']='Mumbai'

# %%
newdata
# Out:
#        name        city  age  score
# 101  Xavier      Mumbai   41   88.0
# 102     Ann     Toronto   28   79.0
# 103    Jana      Prague   33   81.0
# 104      Yi    Shanghai   34   80.0
# 105   Robin  Manchester   38   68.0
# 106    Amal       Cairo   31   61.0
# 107    Nori       Osaka   37   84.0

# %%
newdata[newdata["age"] < 32]
# Out:
#      name     city  age  py-score
# 102   Ann  Toronto   28      79.0
# 106  Amal    Cairo   31      61.0

# %% [markdown]
# # Adding new column

# %%
newdata['Student']='yes'

# %%
newdata
# Out:
#       name        city  age  py-score Student
# 101    Ram      Mumbai   25      88.0     yes
# 102    Ann     Toronto   28      79.0     yes
# 103   Jana      Prague   33      81.0     yes
# 104     Yi    Shanghai   34      80.0     yes
# 105  Robin  Manchester   38      68.0     yes
# 106   Amal       Cairo   31      61.0     yes
# 107   Nori       Osaka   37      84.0     yes

# %%
newdata['Student']=['yes','no','yes','yes','no','no','yes']

# %%
newdata
# Out:
#        name         city  age  py-score Student
# 101  Xavier  Mexico City   41      88.0     yes
# 102     Ann      Toronto   28      79.0      no
# 103    Jana       Prague   33      81.0     yes
# 104      Yi     Shanghai   34      80.0     yes
# 105   Robin   Manchester   38      68.0      no
# 106    Amal        Cairo   31      61.0      no
# 107    Nori        Osaka   37      84.0     yes

# %%
newdata.insert(1, "height", [172, 181, 185, 111, 78, 99, 150])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-20-f832662dc1c5> in <module>
# ----> 1 newdata.insert(1, "height", [172, 181, 185, 111, 78, 99, 150])
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py in insert(self, loc, column, value, allow_duplicates)
#    4412         if not allow_duplicates and column in self.columns:
#    4413             # Should this be a different kind of error??
# -> 4414             raise ValueError(f"cannot insert {column}, already exists")
#    4415         if not isinstance(loc, int):
#    4416             raise TypeError("loc must be int")
#
# ValueError: cannot insert height, already exists

# %%
newdata
# Out:
#        name  height         city  age  py-score Student
# 101  Xavier     172  Mexico City   41      88.0     yes
# 102     Ann     181      Toronto   28      79.0      no
# 103    Jana     185       Prague   33      81.0     yes
# 104      Yi     111     Shanghai   34      80.0     yes
# 105   Robin      78   Manchester   38      68.0      no
# 106    Amal      99        Cairo   31      61.0      no
# 107    Nori     150        Osaka   37      84.0     yes

# %%
newdata.insert(1, "weight", [72, 35, 57, 89, 53, 29, 50])

# %%
newdata.assign(body_mass_index = newdata["weight"] / (newdata["height"] / 100) ** 2)
# Out:
#        name  weight  height         city  age  py-score Student  \
# 101  Xavier      72     172  Mexico City   41      88.0     yes
# 102     Ann      35     181      Toronto   28      79.0      no
# 103    Jana      57     185       Prague   33      81.0     yes
# 104      Yi      89     111     Shanghai   34      80.0     yes
# 105   Robin      53      78   Manchester   38      68.0      no
# 106    Amal      29      99        Cairo   31      61.0      no
# 107    Nori      50     150        Osaka   37      84.0     yes
#
#      body_mass_index
# 101        24.337480
# 102        10.683435
# 103        16.654492
# 104        72.234397
# 105        87.113741
# 106        29.588817
# 107        22.222222

# %%
newdata
# Out:
#        name  weight  height         city  age  py-score Student
# 101  Xavier      72     172  Mexico City   41      88.0     yes
# 102     Ann      35     181      Toronto   28      79.0      no
# 103    Jana      57     185       Prague   33      81.0     yes
# 104      Yi      89     111     Shanghai   34      80.0     yes
# 105   Robin      53      78   Manchester   38      68.0      no
# 106    Amal      29      99        Cairo   31      61.0      no
# 107    Nori      50     150        Osaka   37      84.0     yes

# %%
newdata=newdata.assign(body_mass_index = newdata["weight"] / (newdata["height"] / 100) ** 2)

# %%
newdata
# Out:
#        name  weight  height         city  age  py-score Student  \
# 101  Xavier      72     172  Mexico City   41      88.0     yes
# 102     Ann      35     181      Toronto   28      79.0      no
# 103    Jana      57     185       Prague   33      81.0     yes
# 104      Yi      89     111     Shanghai   34      80.0     yes
# 105   Robin      53      78   Manchester   38      68.0      no
# 106    Amal      29      99        Cairo   31      61.0      no
# 107    Nori      50     150        Osaka   37      84.0     yes
#
#      body_mass_index
# 101        24.337480
# 102        10.683435
# 103        16.654492
# 104        72.234397
# 105        87.113741
# 106        29.588817
# 107        22.222222

# %% [markdown]
# # Sorting

# %%
newdata.sort_index()#ascending=False)
# Out:
#        name  weight  height         city  age  py-score Student  \
# 101  Xavier      72     172  Mexico City   41      88.0     yes
# 102     Ann      35     181      Toronto   28      79.0      no
# 103    Jana      57     185       Prague   33      81.0     yes
# 104      Yi      89     111     Shanghai   34      80.0     yes
# 105   Robin      53      78   Manchester   38      68.0      no
# 106    Amal      29      99        Cairo   31      61.0      no
# 107    Nori      50     150        Osaka   37      84.0     yes
#
#      body_mass_index
# 101        24.337480
# 102        10.683435
# 103        16.654492
# 104        72.234397
# 105        87.113741
# 106        29.588817
# 107        22.222222

# %%
newdata.sort_index(ascending=False)
# Out:
#        name  weight  height         city  age  py-score Student  \
# 107    Nori      50     150        Osaka   37      84.0     yes
# 106    Amal      29      99        Cairo   31      61.0      no
# 105   Robin      53      78   Manchester   38      68.0      no
# 104      Yi      89     111     Shanghai   34      80.0     yes
# 103    Jana      57     185       Prague   33      81.0     yes
# 102     Ann      35     181      Toronto   28      79.0      no
# 101  Xavier      72     172  Mexico City   41      88.0     yes
#
#      body_mass_index
# 107        22.222222
# 106        29.588817
# 105        87.113741
# 104        72.234397
# 103        16.654492
# 102        10.683435
# 101        24.337480

# %%
newdata.sort_values(by="age", inplace=True)

# %%
newdata
# Out:
#        name  weight  height         city  age  py-score Student  \
# 102     Ann      35     181      Toronto   28      79.0      no
# 106    Amal      29      99        Cairo   31      61.0      no
# 103    Jana      57     185       Prague   33      81.0     yes
# 104      Yi      89     111     Shanghai   34      80.0     yes
# 107    Nori      50     150        Osaka   37      84.0     yes
# 105   Robin      53      78   Manchester   38      68.0      no
# 101  Xavier      72     172  Mexico City   41      88.0     yes
#
#      body_mass_index
# 102        10.683435
# 106        29.588817
# 103        16.654492
# 104        72.234397
# 107        22.222222
# 105        87.113741
# 101        24.337480

# %% [markdown]
# # Adding new row

# %%
newdata.loc[110]=['Mala','Cochin',35 , 67,'no']

# %%
newdata
# Out:
#       name        city  age  py-score Student
# 101    Ram      Mumbai   25      88.0     yes
# 102    Ann     Toronto   28      79.0      no
# 103   Jana      Prague   33      81.0     yes
# 104     Yi    Shanghai   34      80.0     yes
# 105  Robin  Manchester   38      68.0      no
# 106   Amal       Cairo   31      61.0      no
# 107   Nori       Osaka   37      84.0     yes
# 110   Mala      Cochin   35      67.0      no

# %% [markdown]
# # Delete Column

# %%
temp=newdata
del newdata['py-score']

# %%
newdata
# Out:
#       name        city  age Student
# 101    Ram      Mumbai   25     yes
# 102    Ann     Toronto   28      no
# 103   Jana      Prague   33     yes
# 104     Yi    Shanghai   34     yes
# 105  Robin  Manchester   38      no
# 106   Amal       Cairo   31      no
# 107   Nori       Osaka   37     yes
# 110   Mala      Cochin   35      no

# %%
newdata.drop(['age','Student'],axis=1,inplace=True)

# %%
newdata
# Out:
#       name        city
# 101    Ram      Mumbai
# 102    Ann     Toronto
# 103   Jana      Prague
# 104     Yi    Shanghai
# 105  Robin  Manchester
# 106   Amal       Cairo
# 107   Nori       Osaka
# 110   Mala      Cochin

# %% [markdown]
# # Delete Row

# %%
newdata.drop([107],axis=0,inplace=True)

# %%
newdata
# Out:
#       name        city
# 101    Ram      Mumbai
# 102    Ann     Toronto
# 103   Jana      Prague
# 104     Yi    Shanghai
# 105  Robin  Manchester
# 106   Amal       Cairo
# 110   Mala      Cochin

# %% [markdown]
# # Replace a value

# %%
newdata.replace("Mala", "Jasmine", inplace=True)

# %%
newdata
# Out:
#         name        city
# 101      Ram      Mumbai
# 102      Ann     Toronto
# 103     Jana      Prague
# 104       Yi    Shanghai
# 105    Robin  Manchester
# 106     Amal       Cairo
# 110  Jasmine      Cochin

# %% [markdown]
# #missing values

# %%
import numpy as np
bonus_array = np.array([[0,np.nan,2],[np.nan,1,0],[0, 1, 0], [3, 3, 0]])
bonus_points = pd.DataFrame(bonus_array, columns=["oct", "nov", "dec"], index=["bob","colin", "darwin", "charles"])
bonus_points
# Out:
#          oct  nov  dec
# bob      0.0  NaN  2.0
# colin    NaN  1.0  0.0
# darwin   0.0  1.0  0.0
# charles  3.0  3.0  0.0

# %%
grades_array = np.array([[8,8,9],[10,9,9],[4, 8, 2], [9, 10, 10]])
grades = pd.DataFrame(grades_array, columns=["sep", "oct", "nov"], index=["alice","bob","charles","darwin"])
grades
# Out:
#          sep  oct  nov
# alice      8    8    9
# bob       10    9    9
# charles    4    8    2
# darwin     9   10   10

# %%
grades+bonus_points
# Out:
#          dec   nov   oct  sep
# alice    NaN   NaN   NaN  NaN
# bob      NaN   NaN   9.0  NaN
# charles  NaN   5.0  11.0  NaN
# colin    NaN   NaN   NaN  NaN
# darwin   NaN  11.0  10.0  NaN

# %% [markdown]
# Looks like the addition worked in some cases but way too many elements are now empty. That's because when aligning the DataFrames, some columns and rows were only present on one side, and thus they were considered missing on the other side (NaN). Then adding NaN to a number results in NaN, hence the result.
#
# Handling missing data
#
# Dealing with missing data is a frequent task when working with real life data. Pandas offers a few tools to handle missing data.
#
# Let's try to fix the problem above. For example, we can decide that missing data should result in a zero, instead of NaN. We can replace all NaN values by a any value using the fillna() method:

# %%
(grades + bonus_points).fillna(0)
# Out:
#          dec   nov   oct  sep
# alice    0.0   0.0   0.0  0.0
# bob      0.0   0.0   9.0  0.0
# charles  0.0   5.0  11.0  0.0
# colin    0.0   0.0   0.0  0.0
# darwin   0.0  11.0  10.0  0.0

# %%
final = grades + bonus_points
final
# Out:
#          dec   nov   oct  sep
# alice    NaN   NaN   NaN  NaN
# bob      NaN   NaN   9.0  NaN
# charles  NaN   5.0  11.0  NaN
# colin    NaN   NaN   NaN  NaN
# darwin   NaN  11.0  10.0  NaN

# %%
final.dropna(how="all")
# Out:
#          dec   nov   oct  sep
# bob      NaN   NaN   9.0  NaN
# charles  NaN   5.0  11.0  NaN
# darwin   NaN  11.0  10.0  NaN

# %%
final
# Out:
#          dec   nov   oct  sep
# alice    NaN   NaN   NaN  NaN
# bob      NaN   NaN   9.0  NaN
# charles  NaN   5.0  11.0  NaN
# colin    NaN   NaN   NaN  NaN
# darwin   NaN  11.0  10.0  NaN

# %%
f=final.dropna(how="all",axis=1)

# %%
f
# Out:
#           nov   oct
# alice     NaN   NaN
# bob       NaN   9.0
# charles   5.0  11.0
# colin     NaN   NaN
# darwin   11.0  10.0

# %%
f.dropna(how="all",axis=0)
# Out:
#           nov   oct
# bob       NaN   9.0
# charles   5.0  11.0
# darwin   11.0  10.0

# %% [markdown]
# # Save Dataframe

# %%
my_df.to_csv("my_df.csv")
my_df.to_html("my_df.html")
my_df.to_json("my_df.json")

# %%
my_df_loaded = pd.read_csv("my_df.csv", index_col=0)
my_df_loaded

# %%
https://realpython.com/pandas-dataframe/#:~:text=The%20Pandas%20DataFrame%20is%20a,with%20in%20Excel%20or%20Calc.
https://towardsdatascience.com/a-quick-introduction-to-the-pandas-python-library-f1b678f34673
https://www.geeksforgeeks.org/python-pandas-dataframe/
# Out:
#   File "<ipython-input-68-0a2e7d916b46>", line 1
#     https://realpython.com/pandas-dataframe/#:~:text=The%20Pandas%20DataFrame%20is%20a,with%20in%20Excel%20or%20Calc.
#            ^
# SyntaxError: invalid syntax
